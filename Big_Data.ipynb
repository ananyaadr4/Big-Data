# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
np.random.seed(10)
random_numbers = np.random.randint(0, 11, size=100)


conf = SparkConf().setAppName("FrequencyCalculation").setMaster("local[*]")
sc = SparkContext(conf=conf)
random_numbers_rdd = sc.parallelize(random_numbers)
number_count_rdd = random_numbers_rdd.map(lambda num: (num, 1))
number_frequencies = number_count_rdd.reduceByKey(lambda x, y: x + y)
result = number_frequencies.collect()

for num, frequency in sorted(result):
    print(f"Number: {num}, Frequency: {frequency}")
sc.stop()
# Out:
# Number: 0, Frequency: 12
# Number: 1, Frequency: 11
# Number: 2, Frequency: 8
# Number: 3, Frequency: 6
# Number: 4, Frequency: 8
# Number: 5, Frequency: 5
# Number: 6, Frequency: 11
# Number: 7, Frequency: 5
# Number: 8, Frequency: 14
# Number: 9, Frequency: 12
# Number: 10, Frequency: 8

# %% [markdown]
# We set the seed for the NumPy random number generator to 10, ensuring reproducibility of random numbers.
#
# Using NumPy's randint function, we generate an array of 100 random integers between 0 and 10 (inclusive).
#
# We configure Spark with an application name "FrequencyCalculation" and set it to run locally using all available cores.
#
# We create an RDD (random_numbers_rdd) from the generated random numbers, map each number to a tuple of (number, 1) for counting (number_count_rdd), reduce by key to calculate the frequency of each number (number_frequencies), collect the results, and print them sorted by number. Finally, we stop the Spark context to release resources.

# %%
from pyspark import SparkContext, SparkConf
conf = SparkConf().setAppName("WordFrequency").setMaster("local[*]")  # Run Spark locally using all available cores
sc = SparkContext(conf=conf)
text8_rdd = sc.textFile("/content/drive/MyDrive/Datasets/text8.txt")
words_rdd = text8_rdd.flatMap(lambda line: line.split())
word_count_rdd = words_rdd.map(lambda word: (word, 1))
word_frequencies = word_count_rdd.reduceByKey(lambda x, y: x + y)
words_with_a = word_frequencies.filter(lambda pair: 'a' in pair[0])
result = words_with_a.collect()
for word, frequency in result:
    print(f"Word: {word}, Frequency: {frequency}")

sc.stop()
# Out:
# Streaming output truncated to the last 5000 lines.
# Word: guacurian, Frequency: 1
# Word: maratino, Frequency: 1
# Word: reca, Frequency: 5
# Word: meckna, Frequency: 1
# Word: rockaway, Frequency: 2
# Word: winlame, Frequency: 1
# Word: sesodia, Frequency: 1
# Word: maximi, Frequency: 1
# Word: lionsbay, Frequency: 1
# Word: zaobao, Frequency: 1
# Word: thairath, Frequency: 1
# Word: matichon, Frequency: 1
# Word: eskalith, Frequency: 1
# Word: anablepidae, Frequency: 1
# Word: moscarda, Frequency: 2
# Word: fontcuberta, Frequency: 1
# Word: distionary, Frequency: 1
# Word: lutra, Frequency: 1
# Word: vinnacia, Frequency: 2
# Word: cannesphotocall, Frequency: 1
# Word: hospitalists, Frequency: 1
# Word: amoron, Frequency: 1
# Word: penaeaceae, Frequency: 2
# Word: facioscapulohumeral, Frequency: 1
# Word: reassuming, Frequency: 1
# Word: matii, Frequency: 1
# Word: bhandup, Frequency: 1
# Word: kaminaljuy, Frequency: 1
# Word: midwayislands, Frequency: 1
# Word: ulaan, Frequency: 1
# Word: capsian, Frequency: 2
# Word: weihenmayer, Frequency: 1
# Word: menafatf, Frequency: 1
# Word: novela, Frequency: 4
# Word: caucused, Frequency: 1
# Word: saoshyant, Frequency: 2
# Word: chicoharpozeppo, Frequency: 2
# Word: magnetoreceptor, Frequency: 3
# Word: elementarily, Frequency: 1
# Word: routenplaner, Frequency: 1
# Word: defoamer, Frequency: 1
# Word: exhorbitant, Frequency: 1
# Word: taymiyyah, Frequency: 1
# Word: apertium, Frequency: 1
# Word: supercatamarans, Frequency: 1
# Word: cyberwar, Frequency: 1
# Word: naqala, Frequency: 1
# Word: statz, Frequency: 1
# Word: paulik, Frequency: 1
# Word: nobukata, Frequency: 1
# Word: zbay, Frequency: 1
# Word: agca, Frequency: 2
# Word: seagren, Frequency: 1
# Word: capuleti, Frequency: 1
# Word: shivaratree, Frequency: 1
# Word: pharma, Frequency: 1
# Word: spia, Frequency: 1
# Word: helcar, Frequency: 1
# Word: incapax, Frequency: 1
# Word: einschienenbahn, Frequency: 1
# Word: judenha, Frequency: 1
# Word: criminalistica, Frequency: 1
# Word: spataro, Frequency: 1
# Word: musicradio, Frequency: 2
# Word: caspi, Frequency: 2
# Word: signficiant, Frequency: 1
# Word: achieved, Frequency: 902
# Word: affection, Frequency: 106
# Word: federally, Frequency: 27
# Word: local, Frequency: 3960
# Word: commercial, Frequency: 2020
# Word: alphabet, Frequency: 1088
# Word: battery, Frequency: 390
# Word: garrison, Frequency: 184
# Word: avenged, Frequency: 20
# Word: qualified, Frequency: 208
# Word: chihuahua, Frequency: 15
# Word: langrell, Frequency: 1
# Word: harpalus, Frequency: 1
# Word: agent, Frequency: 759
# Word: samaritan, Frequency: 31
# Word: andalusi, Frequency: 3
# Word: marrying, Frequency: 96
# Word: loans, Frequency: 167
# Word: dominated, Frequency: 756
# Word: interwar, Frequency: 23
# Word: dovetailed, Frequency: 3
# Word: outreach, Frequency: 32
# Word: birchbark, Frequency: 3
# Word: universals, Frequency: 44
# Word: install, Frequency: 104
# Word: parham, Frequency: 2
# Word: meta, Frequency: 194
# Word: anyway, Frequency: 136
# Word: rwanda, Frequency: 110
# Word: diana, Frequency: 138
# Word: predator, Frequency: 68
# Word: audacity, Frequency: 12
# Word: chadic, Frequency: 33
# Word: attributing, Frequency: 35
# Word: relaunched, Frequency: 14
# Word: kahn, Frequency: 88
# Word: coloma, Frequency: 3
# Word: admitting, Frequency: 51
# Word: glossina, Frequency: 2
# Word: abak, Frequency: 2
# Word: rhubarb, Frequency: 6
# Word: assessments, Frequency: 40
# Word: downrange, Frequency: 2
# Word: ordained, Frequency: 180
# Word: slayton, Frequency: 11
# Word: designations, Frequency: 148
# Word: chatter, Frequency: 10
# Word: dermatitis, Frequency: 7
# Word: quadrant, Frequency: 32
# Word: prevalence, Frequency: 139
# Word: ceeac, Frequency: 8
# Word: popliteal, Frequency: 1
# Word: assault, Frequency: 423
# Word: graptolites, Frequency: 2
# Word: astron, Frequency: 5
# Word: euclidean, Frequency: 289
# Word: regards, Frequency: 190
# Word: rabindranath, Frequency: 15
# Word: afghana, Frequency: 9
# Word: mafia, Frequency: 189
# Word: subhanahu, Frequency: 1
# Word: embarked, Frequency: 112
# Word: armenak, Frequency: 1
# Word: gaku, Frequency: 9
# Word: splashes, Frequency: 7
# Word: aristander, Frequency: 3
# Word: cleopatra, Frequency: 100
# Word: parysatis, Frequency: 1
# Word: stamped, Frequency: 51
# Word: petrosaviaceae, Frequency: 1
# Word: asterid, Frequency: 3
# Word: kali, Frequency: 74
# Word: poignant, Frequency: 17
# Word: maid, Frequency: 81
# Word: haci, Frequency: 3
# Word: parodied, Frequency: 80
# Word: lasky, Frequency: 2
# Word: paced, Frequency: 47
# Word: miscarried, Frequency: 3
# Word: wallpapers, Frequency: 13
# Word: taligent, Frequency: 3
# Word: miklas, Frequency: 4
# Word: basquiat, Frequency: 31
# Word: fayum, Frequency: 4
# Word: determinatives, Frequency: 1
# Word: fasciculations, Frequency: 1
# Word: vaccine, Frequency: 103
# Word: superatom, Frequency: 1
# Word: disciplinary, Frequency: 72
# Word: decennially, Frequency: 2
# Word: existentialism, Frequency: 96
# Word: olfaction, Frequency: 8
# Word: schema, Frequency: 93
# Word: affectional, Frequency: 6
# Word: serialized, Frequency: 21
# Word: redrawn, Frequency: 12
# Word: khaliyeh, Frequency: 2
# Word: periadriatic, Frequency: 1
# Word: traversed, Frequency: 35
# Word: webcam, Frequency: 33
# Word: sparkling, Frequency: 27
# Word: chracter, Frequency: 2
# Word: odessa, Frequency: 27
# Word: navajo, Frequency: 40
# Word: awry, Frequency: 11
# Word: maya, Frequency: 148
# Word: monaco, Frequency: 252
# Word: edvard, Frequency: 31
# Word: qxa, Frequency: 4
# Word: counterargument, Frequency: 6
# Word: marginalist, Frequency: 5
# Word: houmanidis, Frequency: 1
# Word: dakin, Frequency: 3
# Word: lancaster, Frequency: 120
# Word: koran, Frequency: 19
# Word: curiae, Frequency: 9
# Word: spherical, Frequency: 178
# Word: fiona, Frequency: 8
# Word: handshape, Frequency: 3
# Word: schachner, Frequency: 1
# Word: conradin, Frequency: 6
# Word: pompeian, Frequency: 4
# Word: umbrellas, Frequency: 4
# Word: vassilisis, Frequency: 1
# Word: rotates, Frequency: 43
# Word: marambio, Frequency: 1
# Word: biblica, Frequency: 4
# Word: lesbia, Frequency: 6
# Word: jarkoff, Frequency: 1
# Word: bryansk, Frequency: 1
# Word: anchovies, Frequency: 16
# Word: synonymization, Frequency: 1
# Word: authoring, Frequency: 30
# Word: phoebastria, Frequency: 7
# Word: afield, Frequency: 13
# Word: delocalise, Frequency: 1
# Word: krafft, Frequency: 9
# Word: lina, Frequency: 10
# Word: griselda, Frequency: 4
# Word: baronial, Frequency: 2
# Word: anniversarial, Frequency: 1
# Word: ferragosto, Frequency: 1
# Word: xmlgawk, Frequency: 1
# Word: factitious, Frequency: 5
# Word: haereticos, Frequency: 1
# Word: baltaji, Frequency: 1
# Word: cynisca, Frequency: 1
# Word: pursuance, Frequency: 6
# Word: ingratitude, Frequency: 4
# Word: manama, Frequency: 20
# Word: marlee, Frequency: 1
# Word: tilapia, Frequency: 8
# Word: manin, Frequency: 5
# Word: abicht, Frequency: 1
# Word: arbitrio, Frequency: 7
# Word: zainab, Frequency: 6
# Word: erigena, Frequency: 5
# Word: cutanda, Frequency: 2
# Word: boars, Frequency: 7
# Word: evagoras, Frequency: 3
# Word: amm, Frequency: 2
# Word: visage, Frequency: 7
# Word: inartistic, Frequency: 1
# Word: carpine, Frequency: 3
# Word: paterculus, Frequency: 2
# Word: hanbal, Frequency: 1
# Word: andersonville, Frequency: 24
# Word: adaptor, Frequency: 30
# Word: ballesteros, Frequency: 1
# Word: abm, Frequency: 65
# Word: sabratha, Frequency: 4
# Word: sayako, Frequency: 1
# Word: bahuguna, Frequency: 1
# Word: apa, Frequency: 39
# Word: gabrielle, Frequency: 26
# Word: bilabial, Frequency: 38
# Word: sanomat, Frequency: 4
# Word: avi, Frequency: 27
# Word: backside, Frequency: 11
# Word: headhunter, Frequency: 4
# Word: tewahedo, Frequency: 9
# Word: thorsbjaerg, Frequency: 1
# Word: airbender, Frequency: 2
# Word: mandy, Frequency: 34
# Word: jays, Frequency: 36
# Word: playa, Frequency: 16
# Word: amalgam, Frequency: 25
# Word: rationalists, Frequency: 24
# Word: barman, Frequency: 6
# Word: pocahontas, Frequency: 3
# Word: spacepunk, Frequency: 1
# Word: arroces, Frequency: 1
# Word: negra, Frequency: 2
# Word: haryana, Frequency: 31
# Word: taczak, Frequency: 2
# Word: anredsleage, Frequency: 1
# Word: numerological, Frequency: 7
# Word: samokhodnaya, Frequency: 1
# Word: dehydroepiandrosterone, Frequency: 10
# Word: hatfield, Frequency: 92
# Word: unstoppable, Frequency: 10
# Word: mahabharatha, Frequency: 3
# Word: srisailam, Frequency: 1
# Word: antipsychotics, Frequency: 42
# Word: aon, Frequency: 14
# Word: hamsun, Frequency: 29
# Word: sapidus, Frequency: 1
# Word: raff, Frequency: 8
# Word: psychosexual, Frequency: 4
# Word: reorientation, Frequency: 3
# Word: vavi, Frequency: 1
# Word: ribaudequin, Frequency: 1
# Word: beluga, Frequency: 11
# Word: trailed, Frequency: 18
# Word: acsb, Frequency: 1
# Word: abbattis, Frequency: 1
# Word: aeclanensis, Frequency: 1
# Word: ratan, Frequency: 5
# Word: alhandega, Frequency: 1
# Word: guar, Frequency: 2
# Word: shaddai, Frequency: 3
# Word: nealon, Frequency: 2
# Word: bankrate, Frequency: 1
# Word: templates, Frequency: 18
# Word: familiarize, Frequency: 6
# Word: laox, Frequency: 1
# Word: craze, Frequency: 37
# Word: almquist, Frequency: 2
# Word: explicated, Frequency: 11
# Word: typicals, Frequency: 1
# Word: glaxosmithkline, Frequency: 6
# Word: daggerfall, Frequency: 1
# Word: haka, Frequency: 19
# Word: turntablism, Frequency: 4
# Word: ordnance, Frequency: 51
# Word: ahtna, Frequency: 1
# Word: isbahani, Frequency: 1
# Word: nitrosooxybutane, Frequency: 2
# Word: mazzaroth, Frequency: 1
# Word: hogarth, Frequency: 13
# Word: phonation, Frequency: 16
# Word: sparrow, Frequency: 60
# Word: salines, Frequency: 1
# Word: gasolines, Frequency: 12
# Word: ucha, Frequency: 1
# Word: pipal, Frequency: 1
# Word: littlemanateeriver, Frequency: 1
# Word: avifauna, Frequency: 1
# Word: uncharacteristic, Frequency: 9
# Word: teleradiocompany, Frequency: 1
# Word: compaor, Frequency: 10
# Word: amg, Frequency: 11
# Word: trespasses, Frequency: 2
# Word: maglic, Frequency: 1
# Word: carats, Frequency: 20
# Word: frolina, Frequency: 1
# Word: masotti, Frequency: 1
# Word: antoniniana, Frequency: 1
# Word: bai, Frequency: 40
# Word: burah, Frequency: 1
# Word: chlorate, Frequency: 8
# Word: lenbach, Frequency: 2
# Word: bambalis, Frequency: 1
# Word: kula, Frequency: 4
# Word: cranborne, Frequency: 2
# Word: siheyuans, Frequency: 3
# Word: sheraton, Frequency: 2
# Word: smallpipes, Frequency: 2
# Word: racquets, Frequency: 9
# Word: vara, Frequency: 11
# Word: demoralise, Frequency: 1
# Word: subcontractors, Frequency: 4
# Word: williamsville, Frequency: 1
# Word: biohazard, Frequency: 2
# Word: statelessness, Frequency: 4
# Word: actualization, Frequency: 7
# Word: matumbi, Frequency: 1
# Word: carnesecchi, Frequency: 2
# Word: aromatics, Frequency: 6
# Word: chakma, Frequency: 3
# Word: jasimuddin, Frequency: 1
# Word: patronization, Frequency: 1
# Word: barcelonettes, Frequency: 1
# Word: kobylyanskiy, Frequency: 1
# Word: daruma, Frequency: 3
# Word: mwra, Frequency: 2
# Word: heaviness, Frequency: 2
# Word: tavli, Frequency: 2
# Word: gallothi, Frequency: 1
# Word: overestimates, Frequency: 3
# Word: renteria, Frequency: 6
# Word: anezka, Frequency: 1
# Word: wargame, Frequency: 10
# Word: pursuading, Frequency: 1
# Word: midtribulationists, Frequency: 2
# Word: penitance, Frequency: 2
# Word: petrucciani, Frequency: 2
# Word: thuvia, Frequency: 2
# Word: raval, Frequency: 2
# Word: llobera, Frequency: 1
# Word: stringari, Frequency: 1
# Word: phaseolus, Frequency: 2
# Word: humeral, Frequency: 1
# Word: recombinant, Frequency: 31
# Word: icenian, Frequency: 1
# Word: antokoletz, Frequency: 1
# Word: einschlagen, Frequency: 1
# Word: sousaphone, Frequency: 2
# Word: steaming, Frequency: 14
# Word: alltime, Frequency: 3
# Word: unrivalled, Frequency: 7
# Word: manx, Frequency: 166
# Word: infalling, Frequency: 2
# Word: garat, Frequency: 2
# Word: jentilbaratza, Frequency: 1
# Word: headroom, Frequency: 28
# Word: alza, Frequency: 3
# Word: triazolam, Frequency: 1
# Word: hawkish, Frequency: 3
# Word: lifeboats, Frequency: 10
# Word: drazi, Frequency: 1
# Word: sabotaged, Frequency: 8
# Word: drawimage, Frequency: 1
# Word: headwinds, Frequency: 1
# Word: habshis, Frequency: 1
# Word: hairspray, Frequency: 2
# Word: marinebio, Frequency: 3
# Word: saya, Frequency: 16
# Word: jasmuheen, Frequency: 22
# Word: gating, Frequency: 5
# Word: manageably, Frequency: 1
# Word: petarienses, Frequency: 1
# Word: kasmin, Frequency: 1
# Word: craits, Frequency: 1
# Word: haag, Frequency: 13
# Word: watwan, Frequency: 1
# Word: decimation, Frequency: 5
# Word: exonumia, Frequency: 3
# Word: belknap, Frequency: 19
# Word: germano, Frequency: 7
# Word: camilo, Frequency: 10
# Word: conspiracism, Frequency: 5
# Word: lightheadedness, Frequency: 3
# Word: dabou, Frequency: 1
# Word: moslava, Frequency: 2
# Word: dinara, Frequency: 20
# Word: asce, Frequency: 1
# Word: falar, Frequency: 1
# Word: badu, Frequency: 3
# Word: buryat, Frequency: 6
# Word: miklagar, Frequency: 1
# Word: tapeheads, Frequency: 2
# Word: kokand, Frequency: 4
# Word: saarland, Frequency: 14
# Word: vallehermoso, Frequency: 1
# Word: namakika, Frequency: 1
# Word: didieraceae, Frequency: 1
# Word: provincially, Frequency: 4
# Word: gsa, Frequency: 5
# Word: avventure, Frequency: 2
# Word: fugliuola, Frequency: 1
# Word: wagnerites, Frequency: 8
# Word: wallack, Frequency: 1
# Word: unfairnesses, Frequency: 1
# Word: shap, Frequency: 3
# Word: nanning, Frequency: 1
# Word: pecksniffian, Frequency: 1
# Word: carabiner, Frequency: 8
# Word: goaltender, Frequency: 21
# Word: hydroxocobalamin, Frequency: 1
# Word: trappolino, Frequency: 1
# Word: bacar, Frequency: 2
# Word: paetus, Frequency: 1
# Word: faunae, Frequency: 1
# Word: martingale, Frequency: 13
# Word: kniga, Frequency: 1
# Word: stalwart, Frequency: 6
# Word: traumas, Frequency: 15
# Word: veruschka, Frequency: 2
# Word: macrohistorical, Frequency: 2
# Word: chonnam, Frequency: 1
# Word: hirosaki, Frequency: 1
# Word: klaipeda, Frequency: 7
# Word: gdanskiego, Frequency: 1
# Word: wakayama, Frequency: 6
# Word: baldoyle, Frequency: 1
# Word: scordatura, Frequency: 1
# Word: kardiac, Frequency: 3
# Word: dousha, Frequency: 3
# Word: impregnate, Frequency: 7
# Word: rukka, Frequency: 1
# Word: zoanthidea, Frequency: 1
# Word: fellated, Frequency: 2
# Word: ival, Frequency: 1
# Word: republitarianism, Frequency: 1
# Word: grails, Frequency: 3
# Word: sintashta, Frequency: 4
# Word: pasqual, Frequency: 3
# Word: kabin, Frequency: 1
# Word: diabolical, Frequency: 7
# Word: hikari, Frequency: 6
# Word: marcantonio, Frequency: 12
# Word: heathly, Frequency: 1
# Word: carotenemia, Frequency: 2
# Word: jatene, Frequency: 2
# Word: blaiberg, Frequency: 1
# Word: baburen, Frequency: 1
# Word: radiometry, Frequency: 4
# Word: misrepresentations, Frequency: 3
# Word: tiffanie, Frequency: 1
# Word: bakes, Frequency: 2
# Word: pimephales, Frequency: 2
# Word: saunter, Frequency: 1
# Word: slaughterhouses, Frequency: 4
# Word: hamdatah, Frequency: 1
# Word: kinyanav, Frequency: 1
# Word: lysias, Frequency: 3
# Word: recusants, Frequency: 1
# Word: cihuac, Frequency: 1
# Word: mcallan, Frequency: 1
# Word: slanderer, Frequency: 4
# Word: basely, Frequency: 1
# Word: wamsa, Frequency: 1
# Word: bavington, Frequency: 1
# Word: beatson, Frequency: 2
# Word: arbitrated, Frequency: 7
# Word: oralhistorydetails, Frequency: 1
# Word: askja, Frequency: 1
# Word: distributionalism, Frequency: 1
# Word: lunkulansaari, Frequency: 1
# Word: straightened, Frequency: 6
# Word: jiushao, Frequency: 1
# Word: raich, Frequency: 2
# Word: annecy, Frequency: 3
# Word: haslet, Frequency: 1
# Word: agamedes, Frequency: 1
# Word: storageworks, Frequency: 1
# Word: kiskeya, Frequency: 2
# Word: polaroids, Frequency: 2
# Word: titadine, Frequency: 1
# Word: andrie, Frequency: 1
# Word: spyan, Frequency: 1
# Word: algor, Frequency: 1
# Word: messianique, Frequency: 1
# Word: hamfest, Frequency: 1
# Word: abigor, Frequency: 1
# Word: azeotropic, Frequency: 2
# Word: beltramo, Frequency: 1
# Word: adrenalin, Frequency: 3
# Word: mailboxes, Frequency: 10
# Word: randstad, Frequency: 2
# Word: handakuten, Frequency: 7
# Word: wronskians, Frequency: 1
# Word: diagoses, Frequency: 1
# Word: machel, Frequency: 6
# Word: asphaltites, Frequency: 2
# Word: ravana, Frequency: 2
# Word: premillennialist, Frequency: 2
# Word: supernaturally, Frequency: 9
# Word: nanomesh, Frequency: 1
# Word: devaluate, Frequency: 1
# Word: wavefronts, Frequency: 2
# Word: sumatrensis, Frequency: 2
# Word: asmahan, Frequency: 1
# Word: fixations, Frequency: 3
# Word: belanda, Frequency: 1
# Word: taikoproject, Frequency: 1
# Word: dharmoapi, Frequency: 1
# Word: desfrancs, Frequency: 1
# Word: mayzie, Frequency: 1
# Word: ettuttokai, Frequency: 1
# Word: khiva, Frequency: 2
# Word: afgan, Frequency: 1
# Word: chitral, Frequency: 1
# Word: janissary, Frequency: 4
# Word: akerlof, Frequency: 4
# Word: kassandra, Frequency: 1
# Word: interministerial, Frequency: 1
# Word: jablonka, Frequency: 2
# Word: kunia, Frequency: 1
# Word: asml, Frequency: 2
# Word: negatron, Frequency: 1
# Word: kontakte, Frequency: 2
# Word: pithecophaga, Frequency: 1
# Word: mawii, Frequency: 1
# Word: shumard, Frequency: 1
# Word: demonstratio, Frequency: 4
# Word: raindrop, Frequency: 2
# Word: headward, Frequency: 1
# Word: raubal, Frequency: 6
# Word: novaezelandia, Frequency: 1
# Word: pejoratives, Frequency: 3
# Word: afrocentrism, Frequency: 1
# Word: vannick, Frequency: 1
# Word: gameplaying, Frequency: 1
# Word: antiterrorist, Frequency: 2
# Word: liberians, Frequency: 23
# Word: ticuna, Frequency: 1
# Word: jeapes, Frequency: 1
# Word: gearless, Frequency: 3
# Word: paramountcy, Frequency: 1
# Word: hoang, Frequency: 1
# Word: sawara, Frequency: 2
# Word: putka, Frequency: 1
# Word: comitative, Frequency: 2
# Word: uzawa, Frequency: 1
# Word: axetopia, Frequency: 1
# Word: qualche, Frequency: 1
# Word: tramonto, Frequency: 1
# Word: raelians, Frequency: 1
# Word: garhi, Frequency: 2
# Word: crystalinks, Frequency: 1
# Word: vulgatum, Frequency: 1
# Word: cathal, Frequency: 10
# Word: nisibena, Frequency: 2
# Word: nationalno, Frequency: 1
# Word: societatea, Frequency: 2
# Word: jamahiriya, Frequency: 9
# Word: kaptita, Frequency: 1
# Word: toroidal, Frequency: 4
# Word: adamah, Frequency: 3
# Word: michiyasu, Frequency: 2
# Word: vascons, Frequency: 2
# Word: aloro, Frequency: 1
# Word: linetskaya, Frequency: 1
# Word: rausch, Frequency: 3
# Word: balanops, Frequency: 1
# Word: bazett, Frequency: 2
# Word: auldbrass, Frequency: 1
# Word: bedlam, Frequency: 4
# Word: sotilasmestari, Frequency: 2
# Word: cyanuric, Frequency: 1
# Word: janjua, Frequency: 2
# Word: datter, Frequency: 1
# Word: wiltraut, Frequency: 1
# Word: tequesta, Frequency: 1
# Word: tamiami, Frequency: 1
# Word: szab, Frequency: 9
# Word: heptanacci, Frequency: 1
# Word: haken, Frequency: 9
# Word: presheaves, Frequency: 3
# Word: traudl, Frequency: 3
# Word: darknets, Frequency: 1
# Word: chafetz, Frequency: 1
# Word: annuaire, Frequency: 1
# Word: acknowlege, Frequency: 1
# Word: homoousians, Frequency: 3
# Word: bakhtiari, Frequency: 2
# Word: patronize, Frequency: 1
# Word: kollumerland, Frequency: 1
# Word: armm, Frequency: 5
# Word: bicapitalisation, Frequency: 1
# Word: maximop, Frequency: 1
# Word: conceptualisation, Frequency: 1
# Word: failover, Frequency: 1
# Word: estian, Frequency: 1
# Word: joviality, Frequency: 3
# Word: sadlier, Frequency: 1
# Word: aqu, Frequency: 1
# Word: siruela, Frequency: 1
# Word: leopoldinian, Frequency: 1
# Word: tramvia, Frequency: 1
# Word: kasha, Frequency: 1
# Word: simultan, Frequency: 1
# Word: litigators, Frequency: 2
# Word: paperboy, Frequency: 1
# Word: tophatters, Frequency: 3
# Word: spasim, Frequency: 4
# Word: lndal, Frequency: 1
# Word: chattuarii, Frequency: 1
# Word: vulcanologia, Frequency: 1
# Word: analycity, Frequency: 1
# Word: tagl, Frequency: 1
# Word: kitman, Frequency: 1
# Word: anthropolgical, Frequency: 1
# Word: peliza, Frequency: 2
# Word: regiao, Frequency: 1
# Word: bauval, Frequency: 3
# Word: baratheon, Frequency: 5
# Word: hospitalier, Frequency: 1
# Word: shannara, Frequency: 1
# Word: landhaus, Frequency: 1
# Word: okuma, Frequency: 1
# Word: plastically, Frequency: 1
# Word: barnaba, Frequency: 2
# Word: capernaum, Frequency: 3
# Word: genava, Frequency: 1
# Word: aribiter, Frequency: 1
# Word: qiriyat, Frequency: 1
# Word: sueciae, Frequency: 2
# Word: rumination, Frequency: 2
# Word: superordinate, Frequency: 1
# Word: bohemianopera, Frequency: 1
# Word: ompa, Frequency: 1
# Word: pseudepigraphies, Frequency: 1
# Word: educationalist, Frequency: 2
# Word: bordetella, Frequency: 1
# Word: spandrels, Frequency: 1
# Word: udarniks, Frequency: 1
# Word: paralyses, Frequency: 1
# Word: scheda, Frequency: 1
# Word: malgry, Frequency: 1
# Word: akhmyarov, Frequency: 1
# Word: aplite, Frequency: 1
# Word: ishakku, Frequency: 1
# Word: munah, Frequency: 1
# Word: avp, Frequency: 2
# Word: okrzejska, Frequency: 1
# Word: funkmaster, Frequency: 2
# Word: jumhuriyya, Frequency: 1
# Word: rawhide, Frequency: 7
# Word: daltons, Frequency: 4
# Word: premeditation, Frequency: 4
# Word: juda, Frequency: 4
# Word: levinia, Frequency: 1
# Word: hcahw, Frequency: 1
# Word: eleatic, Frequency: 4
# Word: habah, Frequency: 1
# Word: knap, Frequency: 2
# Word: zafira, Frequency: 3
# Word: naturarum, Frequency: 1
# Word: armoniae, Frequency: 1
# Word: histadrut, Frequency: 2
# Word: sabrata, Frequency: 1
# Word: gaay, Frequency: 1
# Word: katuv, Frequency: 1
# Word: zayit, Frequency: 1
# Word: bakbuk, Frequency: 1
# Word: harsha, Frequency: 4
# Word: ghaleb, Frequency: 1
# Word: beatmasters, Frequency: 1
# Word: tlacopan, Frequency: 4
# Word: marangon, Frequency: 1
# Word: apss, Frequency: 2
# Word: namied, Frequency: 1
# Word: ykenai, Frequency: 1
# Word: futanari, Frequency: 1
# Word: seatbones, Frequency: 1
# Word: lohamah, Frequency: 1
# Word: hesychasts, Frequency: 8
# Word: nanoscience, Frequency: 2
# Word: alawites, Frequency: 1
# Word: romancy, Frequency: 1
# Word: bresnan, Frequency: 1
# Word: larne, Frequency: 3
# Word: prada, Frequency: 2
# Word: vaporising, Frequency: 2
# Word: bigham, Frequency: 1
# Word: ayatollahs, Frequency: 1
# Word: nezan, Frequency: 1
# Word: arraganate, Frequency: 1
# Word: tumazzu, Frequency: 1
# Word: demanders, Frequency: 2
# Word: raphidioptera, Frequency: 1
# Word: gadabout, Frequency: 1
# Word: chagreneto, Frequency: 1
# Word: syndiotactism, Frequency: 1
# Word: gallnuts, Frequency: 1
# Word: kurang, Frequency: 1
# Word: archivization, Frequency: 1
# Word: shosha, Frequency: 1
# Word: smartcut, Frequency: 1
# Word: setonaikai, Frequency: 1
# Word: hardal, Frequency: 1
# Word: wagoneers, Frequency: 1
# Word: optica, Frequency: 2
# Word: arbetarbladet, Frequency: 1
# Word: staatlichen, Frequency: 1
# Word: staffer, Frequency: 3
# Word: nadie, Frequency: 1
# Word: burglarizing, Frequency: 1
# Word: seminarian, Frequency: 3
# Word: saralegui, Frequency: 1
# Word: osendarp, Frequency: 2
# Word: bisbal, Frequency: 3
# Word: bashkirtseff, Frequency: 1
# Word: sanma, Frequency: 1
# Word: cardiacs, Frequency: 1
# Word: headright, Frequency: 1
# Word: achaz, Frequency: 1
# Word: yehowram, Frequency: 1
# Word: iaoue, Frequency: 4
# Word: akbarnama, Frequency: 5
# Word: edamame, Frequency: 1
# Word: agemono, Frequency: 1
# Word: afghanistian, Frequency: 1
# Word: paulinianus, Frequency: 1
# Word: arnobius, Frequency: 3
# Word: paustovsky, Frequency: 2
# Word: absolutione, Frequency: 1
# Word: maharil, Frequency: 2
# Word: fallicy, Frequency: 1
# Word: maloc, Frequency: 1
# Word: yarael, Frequency: 1
# Word: parvane, Frequency: 1
# Word: manoevred, Frequency: 1
# Word: lawrod, Frequency: 1
# Word: faylakah, Frequency: 3
# Word: tanayev, Frequency: 1
# Word: kutmasta, Frequency: 2
# Word: gaseyo, Frequency: 1
# Word: uboat, Frequency: 2
# Word: arcturos, Frequency: 1
# Word: cambriae, Frequency: 3
# Word: diabate, Frequency: 1
# Word: lasik, Frequency: 3
# Word: powercat, Frequency: 1
# Word: kanemoto, Frequency: 2
# Word: wazamono, Frequency: 1
# Word: mojaqvam, Frequency: 1
# Word: redtenbacher, Frequency: 1
# Word: phyllophorinae, Frequency: 1
# Word: tamowa, Frequency: 1
# Word: pseudokarst, Frequency: 2
# Word: gwan, Frequency: 1
# Word: hawraman, Frequency: 1
# Word: erdelan, Frequency: 1
# Word: krokola, Frequency: 2
# Word: karafilm, Frequency: 1
# Word: waghenaer, Frequency: 1
# Word: uvininkai, Frequency: 1
# Word: feeback, Frequency: 1
# Word: shdanoff, Frequency: 1
# Word: autozone, Frequency: 2
# Word: ppiyar, Frequency: 1
# Word: kazuyo, Frequency: 1
# Word: virtuals, Frequency: 2
# Word: verwarring, Frequency: 1
# Word: zemga, Frequency: 1
# Word: aljadeed, Frequency: 1
# Word: stringham, Frequency: 1
# Word: nessiteras, Frequency: 2
# Word: luftvaf, Frequency: 1
# Word: ohmsha, Frequency: 1
# Word: zenithal, Frequency: 1
# Word: septimanian, Frequency: 1
# Word: medievalized, Frequency: 1
# Word: kvea, Frequency: 1
# Word: aeroperu, Frequency: 1
# Word: hallein, Frequency: 1
# Word: bhimrao, Frequency: 1
# Word: palekar, Frequency: 1
# Word: uttam, Frequency: 2
# Word: adminstrators, Frequency: 1
# Word: szabadif, Frequency: 1
# Word: crumenam, Frequency: 1
# Word: scaglione, Frequency: 1
# Word: daum, Frequency: 2
# Word: plura, Frequency: 1
# Word: sportal, Frequency: 1
# Word: islandshire, Frequency: 1
# Word: gentenaar, Frequency: 1
# Word: slavonije, Frequency: 1
# Word: horas, Frequency: 1
# Word: lausodunon, Frequency: 1
# Word: draize, Frequency: 1
# Word: matik, Frequency: 1
# Word: marylanders, Frequency: 3
# Word: preslar, Frequency: 6
# Word: khuzaimah, Frequency: 1
# Word: wackett, Frequency: 1
# Word: sotcaa, Frequency: 1
# Word: dynatec, Frequency: 1
# Word: oculopharyngeal, Frequency: 1
# Word: reepalu, Frequency: 1
# Word: wirkkala, Frequency: 1
# Word: haikou, Frequency: 1
# Word: acquiesence, Frequency: 1
# Word: deacidify, Frequency: 2
# Word: ayoun, Frequency: 1
# Word: ukrainains, Frequency: 1
# Word: rachidia, Frequency: 1
# Word: duanzong, Frequency: 1
# Word: saalim, Frequency: 1
# Word: zuta, Frequency: 1
# Word: cinematics, Frequency: 1
# Word: naturopathist, Frequency: 1
# Word: pamphamer, Frequency: 1
# Word: lucasfan, Frequency: 1
# Word: marktheidenfeld, Frequency: 1
# Word: spareribs, Frequency: 1
# Word: kamoun, Frequency: 1
# Word: daill, Frequency: 1
# Word: khutbah, Frequency: 1
# Word: plaintalk, Frequency: 2
# Word: inadmissability, Frequency: 1
# Word: jackinworld, Frequency: 1
# Word: vindobona, Frequency: 1
# Word: chetham, Frequency: 2
# Word: ogain, Frequency: 1
# Word: vrishabha, Frequency: 1
# Word: metabolismos, Frequency: 1
# Word: amnioinfusion, Frequency: 1
# Word: bachem, Frequency: 2
# Word: macdermot, Frequency: 1
# Word: haldensleben, Frequency: 2
# Word: habitues, Frequency: 1
# Word: farago, Frequency: 4
# Word: nashik, Frequency: 3
# Word: laa, Frequency: 1
# Word: kadishai, Frequency: 1
# Word: fuencarral, Frequency: 1
# Word: gumilah, Frequency: 1
# Word: malikah, Frequency: 1
# Word: gwenddolau, Frequency: 3
# Word: almera, Frequency: 1
# Word: quartinus, Frequency: 2
# Word: pollakov, Frequency: 1
# Word: labelled, Frequency: 152
# Word: clearly, Frequency: 889
# Word: pacifism, Frequency: 37
# Word: each, Frequency: 9500
# Word: vain, Frequency: 77
# Word: clinicians, Frequency: 21
# Word: san, Frequency: 1737
# Word: disease, Frequency: 1509
# Word: egyptian, Frequency: 852
# Word: olympias, Frequency: 12
# Word: admitted, Frequency: 445
# Word: lawyer, Frequency: 319
# Word: kearns, Frequency: 9
# Word: nationalistic, Frequency: 47
# Word: campaigned, Frequency: 81
# Word: pray, Frequency: 116
# Word: fascinated, Frequency: 66
# Word: actor, Frequency: 3451
# Word: charles, Frequency: 3268
# Word: classics, Frequency: 255
# Word: predicated, Frequency: 19
# Word: banned, Frequency: 499
# Word: participation, Frequency: 473
# Word: stamp, Frequency: 210
# Word: problematic, Frequency: 160
# Word: artesian, Frequency: 8
# Word: equalization, Frequency: 17
# Word: excommunicated, Frequency: 89
# Word: trait, Frequency: 109
# Word: luca, Frequency: 49
# Word: geographic, Frequency: 496
# Word: civilisations, Frequency: 19
# Word: magnetometers, Frequency: 3
# Word: sustainable, Frequency: 88
# Word: metallurgical, Frequency: 31
# Word: limitations, Frequency: 317
# Word: nityanadhiya, Frequency: 1
# Word: explorations, Frequency: 55
# Word: mystical, Frequency: 195
# Word: natrium, Frequency: 3
# Word: monas, Frequency: 5
# Word: takahashi, Frequency: 8
# Word: babenbergs, Frequency: 1
# Word: maria, Frequency: 611
# Word: paranthropus, Frequency: 13
# Word: canary, Frequency: 129
# Word: pythian, Frequency: 7
# Word: vegas, Frequency: 179
# Word: harvest, Frequency: 154
# Word: inaccessible, Frequency: 53
# Word: riordan, Frequency: 9
# Word: faostat, Frequency: 3
# Word: ardor, Frequency: 7
# Word: vascular, Frequency: 48
# Word: synperiplanar, Frequency: 1
# Word: idealised, Frequency: 12
# Word: tribunals, Frequency: 60
# Word: vertically, Frequency: 123
# Word: carminic, Frequency: 1
# Word: laid, Frequency: 586
# Word: preparations, Frequency: 129
# Word: inertial, Frequency: 182
# Word: slovak, Frequency: 117
# Word: germanic, Frequency: 735
# Word: cinematic, Frequency: 67
# Word: arkady, Frequency: 7
# Word: swan, Frequency: 110
# Word: kellermaniana, Frequency: 1
# Word: zuccarinii, Frequency: 1
# Word: ayo, Frequency: 3
# Word: intelligentsia, Frequency: 20
# Word: patrone, Frequency: 4
# Word: seahorses, Frequency: 2
# Word: olympia, Frequency: 75
# Word: durand, Frequency: 24
# Word: yoshinkan, Frequency: 11
# Word: shihan, Frequency: 2
# Word: palaces, Frequency: 79
# Word: medically, Frequency: 40
# Word: forehead, Frequency: 45
# Word: doryanthaceae, Frequency: 2
# Word: diameters, Frequency: 27
# Word: taker, Frequency: 13
# Word: fairy, Frequency: 129
# Word: sagas, Frequency: 32
# Word: volga, Frequency: 73
# Word: samkalden, Frequency: 1
# Word: lasalle, Frequency: 8
# Word: carfree, Frequency: 2
# Word: airbags, Frequency: 7
# Word: carlo, Frequency: 149
# Word: naw, Frequency: 8
# Word: briomhar, Frequency: 1
# Word: extortionate, Frequency: 2
# Word: hieratic, Frequency: 7
# Word: corticospinal, Frequency: 3
# Word: pali, Frequency: 40
# Word: colossal, Frequency: 36
# Word: handheld, Frequency: 131
# Word: decays, Frequency: 48
# Word: antiprotons, Frequency: 19
# Word: tantalum, Frequency: 8
# Word: picardy, Frequency: 12
# Word: bolax, Frequency: 1
# Word: earl, Frequency: 714
# Word: proportionate, Frequency: 15
# Word: sustinance, Frequency: 1
# Word: fallible, Frequency: 7
# Word: mahdi, Frequency: 29
# Word: bettina, Frequency: 7
# Word: bombardments, Frequency: 5
# Word: raimundo, Frequency: 4
# Word: naturalist, Frequency: 122
# Word: conjugated, Frequency: 43
# Word: initiatory, Frequency: 7
# Word: kommunefakta, Frequency: 3
# Word: abatements, Frequency: 1
# Word: sardonic, Frequency: 19
# Word: sancta, Frequency: 12
# Word: reggiani, Frequency: 4
# Word: allegret, Frequency: 2
# Word: amoureuse, Frequency: 1
# Word: divination, Frequency: 74
# Word: aradia, Frequency: 8
# Word: addaula, Frequency: 2
# Word: langes, Frequency: 2
# Word: enthralling, Frequency: 4
# Word: chaundry, Frequency: 2
# Word: flats, Frequency: 85
# Word: ferranti, Frequency: 14
# Word: ingratiated, Frequency: 1
# Word: damper, Frequency: 9
# Word: accomplice, Frequency: 13
# Word: praeparatio, Frequency: 6
# Word: angelopoulos, Frequency: 1
# Word: nordamerikano, Frequency: 1
# Word: constantius, Frequency: 78
# Word: anisotropic, Frequency: 27
# Word: stratovolcano, Frequency: 8
# Word: realencykl, Frequency: 1
# Word: zusammenhang, Frequency: 1
# Word: apoc, Frequency: 1
# Word: taber, Frequency: 4
# Word: intervarsity, Frequency: 10
# Word: planar, Frequency: 44
# Word: austerities, Frequency: 7
# Word: miandra, Frequency: 1
# Word: poincare, Frequency: 4
# Word: brigham, Frequency: 87
# Word: silvia, Frequency: 14
# Word: masterson, Frequency: 6
# Word: apachecon, Frequency: 2
# Word: cabaray, Frequency: 1
# Word: macizo, Frequency: 4
# Word: anchovy, Frequency: 3
# Word: rainwater, Frequency: 24
# Word: carat, Frequency: 58
# Word: iambic, Frequency: 42
# Word: mollymawk, Frequency: 1
# Word: westenra, Frequency: 7
# Word: salutis, Frequency: 6
# Word: pneuma, Frequency: 8
# Word: trance, Frequency: 78
# Word: tabares, Frequency: 1
# Word: kvarner, Frequency: 3
# Word: bora, Frequency: 6
# Word: imagineers, Frequency: 1
# Word: madura, Frequency: 8
# Word: privatus, Frequency: 2
# Word: ephemera, Frequency: 6
# Word: adalbrecht, Frequency: 1
# Word: margrave, Frequency: 83
# Word: electroacupuncture, Frequency: 1
# Word: hindustani, Frequency: 33
# Word: chamfort, Frequency: 2
# Word: agam, Frequency: 8
# Word: peacemaking, Frequency: 8
# Word: desolation, Frequency: 16
# Word: breviarium, Frequency: 3
# Word: neutrals, Frequency: 3
# Word: francophile, Frequency: 2
# Word: wulfstan, Frequency: 6
# Word: deslongchamps, Frequency: 1
# Word: consummate, Frequency: 15
# Word: hyderabad, Frequency: 48
# Word: cryogenically, Frequency: 6
# Word: fatha, Frequency: 3
# Word: maggie, Frequency: 64
# Word: alciata, Frequency: 1
# Word: anatha, Frequency: 2
# Word: arhat, Frequency: 4
# Word: mahakashyapa, Frequency: 4
# Word: agdaman, Frequency: 1
# Word: indomalaya, Frequency: 2
# Word: psoriatic, Frequency: 2
# Word: vasarely, Frequency: 1
# Word: airframes, Frequency: 12
# Word: apologising, Frequency: 1
# Word: nay, Frequency: 22
# Word: martianus, Frequency: 3
# Word: manyara, Frequency: 1
# Word: pataphysics, Frequency: 7
# Word: waleed, Frequency: 7
# Word: ampicillin, Frequency: 8
# Word: pathogen, Frequency: 31
# Word: appall, Frequency: 1
# Word: quapaw, Frequency: 3
# Word: firebrand, Frequency: 8
# Word: stratocruiser, Frequency: 2
# Word: reprobation, Frequency: 1
# Word: malick, Frequency: 4
# Word: rajsko, Frequency: 1
# Word: donatists, Frequency: 7
# Word: parthenopeus, Frequency: 1
# Word: alleges, Frequency: 19
# Word: bakersfield, Frequency: 22
# Word: goodspeedupdate, Frequency: 1
# Word: clancy, Frequency: 23
# Word: katarche, Frequency: 1
# Word: duckula, Frequency: 2
# Word: custard, Frequency: 29
# Word: teamo, Frequency: 1
# Word: impersonal, Frequency: 35
# Word: abacavir, Frequency: 1
# Word: saracen, Frequency: 4
# Word: flan, Frequency: 4
# Word: mandiy, Frequency: 3
# Word: asymptotic, Frequency: 27
# Word: matzleinsdorfer, Frequency: 1
# Word: agf, Frequency: 5
# Word: crosstalk, Frequency: 6
# Word: klasse, Frequency: 4
# Word: carthagensis, Frequency: 1
# Word: ayahausca, Frequency: 1
# Word: solanine, Frequency: 1
# Word: gunaga, Frequency: 1
# Word: shakas, Frequency: 1
# Word: vijaya, Frequency: 4
# Word: anstalt, Frequency: 2
# Word: anodising, Frequency: 2
# Word: moravian, Frequency: 28
# Word: laserdisc, Frequency: 10
# Word: karloff, Frequency: 24
# Word: arjumand, Frequency: 1
# Word: christianizing, Frequency: 4
# Word: pauropoda, Frequency: 1
# Word: frayn, Frequency: 3
# Word: landamm, Frequency: 1
# Word: slezak, Frequency: 1
# Word: weleda, Frequency: 1
# Word: reamins, Frequency: 1
# Word: ritalin, Frequency: 8
# Word: defoliant, Frequency: 1
# Word: pacatianus, Frequency: 1
# Word: carmyllie, Frequency: 1
# Word: bodyslam, Frequency: 2
# Word: kotlyarevsky, Frequency: 1
# Word: desjardins, Frequency: 3
# Word: nea, Frequency: 24
# Word: banpur, Frequency: 1
# Word: distantiam, Frequency: 1
# Word: nanga, Frequency: 3
# Word: autodesk, Frequency: 25
# Word: ultima, Frequency: 24
# Word: kago, Frequency: 2
# Word: hannigan, Frequency: 4
# Word: jemappes, Frequency: 1
# Word: aromanians, Frequency: 4
# Word: tongass, Frequency: 2
# Word: kusseima, Frequency: 1
# Word: platformers, Frequency: 3
# Word: lumumba, Frequency: 15
# Word: archduchy, Frequency: 2
# Word: slovaks, Frequency: 19
# Word: abracalan, Frequency: 1
# Word: troodontidae, Frequency: 2
# Word: analcme, Frequency: 1
# Word: hereditarian, Frequency: 4
# Word: pals, Frequency: 13
# Word: hotlanta, Frequency: 1
# Word: lhas, Frequency: 1
# Word: replicating, Frequency: 71
# Word: reappears, Frequency: 13
# Word: astables, Frequency: 2
# Word: sambunigrin, Frequency: 1
# Word: organismic, Frequency: 5
# Word: caenorhabditis, Frequency: 9
# Word: nightmarishly, Frequency: 2
# Word: overambitious, Frequency: 3
# Word: pelecaniformes, Frequency: 2
# Word: saurischian, Frequency: 3
# Word: bryostatins, Frequency: 1
# Word: cymbals, Frequency: 73
# Word: chagosians, Frequency: 1
# Word: whampoa, Frequency: 10
# Word: paho, Frequency: 3
# Word: ibama, Frequency: 1
# Word: internazionalista, Frequency: 1
# Word: boondael, Frequency: 1
# Word: asuming, Frequency: 1
# Word: izena, Frequency: 1
# Word: snatcher, Frequency: 8
# Word: myostatin, Frequency: 4
# Word: bane, Frequency: 26
# Word: perborate, Frequency: 3
# Word: bundestage, Frequency: 2
# Word: inal, Frequency: 2
# Word: dovetails, Frequency: 2
# Word: banjitar, Frequency: 1
# Word: bethpage, Frequency: 1
# Word: mareth, Frequency: 2
# Word: outflanking, Frequency: 2
# Word: yoshitaka, Frequency: 9
# Word: chaobai, Frequency: 2
# Word: xuanwu, Frequency: 1
# Word: manhan, Frequency: 1
# Word: gaita, Frequency: 2
# Word: kickstand, Frequency: 2
# Word: buffalobraves, Frequency: 1
# Word: upanishad, Frequency: 8
# Word: spokanites, Frequency: 2
# Word: quickbasic, Frequency: 5
# Word: battlewagons, Frequency: 2
# Word: evolvable, Frequency: 4
# Word: settignano, Frequency: 1
# Word: mbar, Frequency: 2
# Word: branes, Frequency: 6
# Word: songoora, Frequency: 1
# Word: zemba, Frequency: 1
# Word: kwanyama, Frequency: 1
# Word: sungai, Frequency: 2
# Word: carcinogenesis, Frequency: 2
# Word: sudovian, Frequency: 1
# Word: yotvingian, Frequency: 1
# Word: choitanyo, Frequency: 1
# Word: sarabande, Frequency: 9
# Word: taskforces, Frequency: 1
# Word: edma, Frequency: 1
# Word: malaika, Frequency: 1
# Word: shaolinsi, Frequency: 1
# Word: barking, Frequency: 26
# Word: babilu, Frequency: 1
# Word: rans, Frequency: 1
# Word: lurkalot, Frequency: 2
# Word: serah, Frequency: 3
# Word: hystapes, Frequency: 1
# Word: organises, Frequency: 8
# Word: railtrack, Frequency: 9
# Word: martijn, Frequency: 1
# Word: fabrika, Frequency: 1
# Word: canadensis, Frequency: 7
# Word: stica, Frequency: 4
# Word: chillida, Frequency: 1
# Word: froissart, Frequency: 13
# Word: bluecoat, Frequency: 1
# Word: latinicised, Frequency: 1
# Word: fadeev, Frequency: 2
# Word: qingzang, Frequency: 1
# Word: skrivanerien, Frequency: 1
# Word: unwary, Frequency: 3
# Word: aadnani, Frequency: 1
# Word: washrooms, Frequency: 2
# Word: jaba, Frequency: 3
# Word: maxent, Frequency: 3
# Word: barbagia, Frequency: 9
# Word: ollolai, Frequency: 1
# Word: oriflamme, Frequency: 2
# Word: bergera, Frequency: 1
# Word: wallie, Frequency: 2
# Word: enumerative, Frequency: 10
# Word: republicae, Frequency: 1
# Word: reinstating, Frequency: 9
# Word: schickard, Frequency: 5
# Word: bartosek, Frequency: 1
# Word: visualizations, Frequency: 4
# Word: pentapolis, Frequency: 4
# Word: movna, Frequency: 3
# Word: largeau, Frequency: 2
# Word: chatterley, Frequency: 1
# Word: duckmantian, Frequency: 1
# Word: contredanse, Frequency: 3
# Word: preload, Frequency: 2
# Word: arrhythmogenic, Frequency: 3
# Word: pulmonale, Frequency: 1
# Word: ukgreat, Frequency: 1
# Word: escobar, Frequency: 15
# Word: savudrija, Frequency: 1
# Word: troya, Frequency: 2
# Word: antillana, Frequency: 1
# Word: zvati, Frequency: 3
# Word: bianchinetta, Frequency: 1
# Word: camborne, Frequency: 4
# Word: padstow, Frequency: 1
# Word: onecare, Frequency: 1
# Word: malcontents, Frequency: 3
# Word: rhabdodendraceae, Frequency: 1
# Word: graudate, Frequency: 1
# Word: abramson, Frequency: 6
# Word: afrikadey, Frequency: 1
# Word: wheatfields, Frequency: 1
# Word: mcgreal, Frequency: 2
# Word: skymaster, Frequency: 5
# Word: chalcos, Frequency: 1
# Word: dissonances, Frequency: 6
# Word: respirator, Frequency: 4
# Word: ldsfaq, Frequency: 1
# Word: musikalisches, Frequency: 2
# Word: systematization, Frequency: 6
# Word: canadiennes, Frequency: 2
# Word: djalili, Frequency: 1
# Word: pragmaticism, Frequency: 5
# Word: caussa, Frequency: 1
# Word: plautia, Frequency: 1
# Word: soya, Frequency: 5
# Word: lindahl, Frequency: 8
# Word: darrington, Frequency: 1
# Word: agoura, Frequency: 3
# Word: bordalo, Frequency: 1
# Word: ppna, Frequency: 1
# Word: lamella, Frequency: 1
# Word: dryad, Frequency: 1
# Word: grammatik, Frequency: 12
# Word: statins, Frequency: 1
# Word: fragmenting, Frequency: 7
# Word: landres, Frequency: 1
# Word: unglazed, Frequency: 3
# Word: laing, Frequency: 9
# Word: niigata, Frequency: 13
# Word: franche, Frequency: 4
# Word: tomographical, Frequency: 1
# Word: kinsealy, Frequency: 1
# Word: apprendre, Frequency: 1
# Word: spiccato, Frequency: 4
# Word: ambrones, Frequency: 3
# Word: carthon, Frequency: 1
# Word: daskalogiannis, Frequency: 1
# Word: sealable, Frequency: 1
# Word: magazu, Frequency: 1
# Word: totall, Frequency: 1
# Word: gato, Frequency: 1
# Word: nematocysts, Frequency: 4
# Word: hydrozoa, Frequency: 6
# Word: strayhorn, Frequency: 1
# Word: jspa, Frequency: 1
# Word: maltija, Frequency: 1
# Word: varaam, Frequency: 1
# Word: dolyares, Frequency: 1
# Word: balik, Frequency: 1
# Word: dromadaires, Frequency: 1
# Word: judaeans, Frequency: 1
# Word: gager, Frequency: 2
# Word: mainlander, Frequency: 3
# Word: aldag, Frequency: 1
# Word: consecrates, Frequency: 1
# Word: eliahu, Frequency: 3
# Word: aphthona, Frequency: 1
# Word: collates, Frequency: 4
# Word: crann, Frequency: 3
# Word: downplaying, Frequency: 5
# Word: nikondigital, Frequency: 1
# Word: mamluks, Frequency: 9
# Word: mesencephalic, Frequency: 3
# Word: schiavoni, Frequency: 1
# Word: labtutorials, Frequency: 1
# Word: vang, Frequency: 6
# Word: gional, Frequency: 3
# Word: gratification, Frequency: 8
# Word: antigonish, Frequency: 4
# Word: marcinko, Frequency: 1
# Word: natriuretic, Frequency: 3
# Word: mamlekhet, Frequency: 1
# Word: kervanu, Frequency: 1
# Word: aloneness, Frequency: 1
# Word: sumbawa, Frequency: 6
# Word: meliae, Frequency: 1
# Word: cyclopia, Frequency: 1
# Word: hsiao, Frequency: 1
# Word: uzzano, Frequency: 1
# Word: prefessional, Frequency: 1
# Word: plama, Frequency: 1
# Word: abcababcab, Frequency: 1
# Word: jaran, Frequency: 1
# Word: phokida, Frequency: 1
# Word: tami, Frequency: 3
# Word: cappucino, Frequency: 1
# Word: mandibular, Frequency: 2
# Word: congolais, Frequency: 2
# Word: jamao, Frequency: 1
# Word: catness, Frequency: 1
# Word: cavalleiro, Frequency: 1
# Word: cudbear, Frequency: 1
# Word: allingham, Frequency: 2
# Word: glauser, Frequency: 1
# Word: manwatching, Frequency: 2
# Word: serralles, Frequency: 1
# Word: boulangers, Frequency: 1
# Word: newbattle, Frequency: 1
# Word: azbab, Frequency: 1
# Word: avians, Frequency: 1
# Word: lawler, Frequency: 4
# Word: shinzaki, Frequency: 1
# Word: quartetto, Frequency: 4
# Word: antri, Frequency: 1
# Word: turbocharger, Frequency: 10
# Word: disambiguate, Frequency: 11
# Word: jaian, Frequency: 12
# Word: rapf, Frequency: 1
# Word: blastomere, Frequency: 1
# Word: ravin, Frequency: 1
# Word: dachsie, Frequency: 1
# Word: frash, Frequency: 2
# Word: nogah, Frequency: 1
# Word: vacillated, Frequency: 3
# Word: warcries, Frequency: 4
# Word: thefa, Frequency: 1
# Word: mandeel, Frequency: 1
# Word: lamel, Frequency: 1
# Word: expirations, Frequency: 1
# Word: graphology, Frequency: 1
# Word: apppearances, Frequency: 1
# Word: deprogrammee, Frequency: 1
# Word: halanta, Frequency: 2
# Word: hapy, Frequency: 1
# Word: vasus, Frequency: 2
# Word: micas, Frequency: 10
# Word: simulataneous, Frequency: 1
# Word: plansprachen, Frequency: 1
# Word: chiffriermaschinen, Frequency: 2
# Word: furan, Frequency: 2
# Word: elephantidae, Frequency: 3
# Word: palta, Frequency: 1
# Word: muatetema, Frequency: 1
# Word: danicarum, Frequency: 1
# Word: informationsf, Frequency: 1
# Word: dziggetai, Frequency: 2
# Word: oquassa, Frequency: 1
# Word: pzazz, Frequency: 1
# Word: ashfalls, Frequency: 1
# Word: gbase, Frequency: 14
# Word: gabelsberger, Frequency: 2
# Word: uncia, Frequency: 8
# Word: leari, Frequency: 1
# Word: eurocrats, Frequency: 1
# Word: rheita, Frequency: 1
# Word: bearbeitet, Frequency: 1
# Word: uage, Frequency: 1
# Word: almshouses, Frequency: 1
# Word: watercourses, Frequency: 8
# Word: retallack, Frequency: 1
# Word: kayley, Frequency: 1
# Word: solitaria, Frequency: 1
# Word: wahlsten, Frequency: 1
# Word: gaya, Frequency: 2
# Word: vivaine, Frequency: 1
# Word: schinau, Frequency: 1
# Word: vassiliou, Frequency: 1
# Word: janski, Frequency: 1
# Word: willam, Frequency: 2
# Word: annamites, Frequency: 2
# Word: sapponi, Frequency: 1
# Word: nahanni, Frequency: 2
# Word: ventrally, Frequency: 1
# Word: caesoninus, Frequency: 2
# Word: paucis, Frequency: 1
# Word: eadem, Frequency: 1
# Word: vastlad, Frequency: 1
# Word: fitzmaurice, Frequency: 3
# Word: gurkan, Frequency: 1
# Word: tayfun, Frequency: 1
# Word: cosma, Frequency: 2
# Word: essaying, Frequency: 1
# Word: gusta, Frequency: 1
# Word: blua, Frequency: 5
# Word: misemaruyama, Frequency: 1
# Word: iah, Frequency: 5
# Word: sirotta, Frequency: 4
# Word: paral, Frequency: 1
# Word: schaul, Frequency: 1
# Word: assholes, Frequency: 1
# Word: auriol, Frequency: 1
# Word: damerment, Frequency: 1
# Word: moorea, Frequency: 1
# Word: zulawski, Frequency: 1
# Word: dialectically, Frequency: 3
# Word: speculatively, Frequency: 7
# Word: kustannus, Frequency: 1
# Word: telautograph, Frequency: 1
# Word: desiginated, Frequency: 3
# Word: spaceframe, Frequency: 1
# Word: landarzt, Frequency: 1
# Word: leyva, Frequency: 1
# Word: alencastre, Frequency: 1
# Word: glinka, Frequency: 3
# Word: anchorman, Frequency: 3
# Word: forestrylandforms, Frequency: 1
# Word: eqa, Frequency: 2
# Word: backticks, Frequency: 1
# Word: murtala, Frequency: 1
# Word: launay, Frequency: 2
# Word: monarchiens, Frequency: 1
# Word: magasinet, Frequency: 1
# Word: sarnen, Frequency: 1
# Word: franeker, Frequency: 1
# Word: menaldumadeel, Frequency: 1
# Word: zakaris, Frequency: 1
# Word: antiblue, Frequency: 1
# Word: maximizers, Frequency: 1
# Word: clammy, Frequency: 2
# Word: acia, Frequency: 3
# Word: acom, Frequency: 1
# Word: bridgetalk, Frequency: 1
# Word: candygrammar, Frequency: 1
# Word: codewalker, Frequency: 1
# Word: cruncha, Frequency: 3
# Word: ampd, Frequency: 1
# Word: firebreaks, Frequency: 2
# Word: mutterland, Frequency: 2
# Word: burggraf, Frequency: 1
# Word: strangeways, Frequency: 3
# Word: freeland, Frequency: 6
# Word: aventure, Frequency: 4
# Word: calendau, Frequency: 1
# Word: inharmonic, Frequency: 3
# Word: faglig, Frequency: 1
# Word: channelers, Frequency: 1
# Word: gantries, Frequency: 1
# Word: actualisation, Frequency: 1
# Word: veljessota, Frequency: 1
# Word: equilibriated, Frequency: 1
# Word: equilibrating, Frequency: 1
# Word: yehezkal, Frequency: 2
# Word: nanus, Frequency: 1
# Word: gnuab, Frequency: 1
# Word: quamu, Frequency: 1
# Word: clavis, Frequency: 1
# Word: veniat, Frequency: 1
# Word: sakusen, Frequency: 1
# Word: kumonga, Frequency: 3
# Word: saradian, Frequency: 2
# Word: rootschat, Frequency: 1
# Word: hotelarstwa, Frequency: 1
# Word: lavrion, Frequency: 1
# Word: quartiers, Frequency: 4
# Word: parturition, Frequency: 1
# Word: kongesangen, Frequency: 1
# Word: knavish, Frequency: 1
# Word: adwords, Frequency: 1
# Word: grapevines, Frequency: 10
# Word: emsland, Frequency: 4
# Word: tyropita, Frequency: 1
# Word: hartwick, Frequency: 1
# Word: sextarius, Frequency: 1
# Word: gpsbabel, Frequency: 1
# Word: physikalische, Frequency: 2
# Word: browa, Frequency: 4
# Word: bignonia, Frequency: 1
# Word: scoreraw, Frequency: 1
# Word: stawia, Frequency: 1
# Word: crystallizations, Frequency: 1
# Word: planetgrandtheftauto, Frequency: 1
# Word: mielivaltaisesti, Frequency: 1
# Word: imasu, Frequency: 1
# Word: bhatinda, Frequency: 1
# Word: wrzesnia, Frequency: 1
# Word: anncouned, Frequency: 1
# Word: waterwheels, Frequency: 4
# Word: afriki, Frequency: 1
# Word: letterheads, Frequency: 1
# Word: prehistorians, Frequency: 1
# Word: imagists, Frequency: 1
# Word: badoh, Frequency: 1
# Word: hexadecimally, Frequency: 1
# Word: copebeatified, Frequency: 1
# Word: estradiol, Frequency: 1
# Word: ascenso, Frequency: 1
# Word: anach, Frequency: 1
# Word: brahmsmuseum, Frequency: 1
# Word: berlina, Frequency: 1
# Word: uncached, Frequency: 1
# Word: antechamber, Frequency: 1
# Word: animalintex, Frequency: 1
# Word: riegal, Frequency: 1
# Word: kyaa, Frequency: 2
# Word: intoxicants, Frequency: 3
# Word: radd, Frequency: 2
# Word: cyberdreams, Frequency: 1
# Word: earing, Frequency: 1
# Word: mizrachim, Frequency: 2
# Word: mengham, Frequency: 1
# Word: sefardi, Frequency: 3
# Word: yameen, Frequency: 2
# Word: abolfazl, Frequency: 1
# Word: inalienably, Frequency: 1
# Word: takamura, Frequency: 2
# Word: niedersachsen, Frequency: 4
# Word: pandeli, Frequency: 2
# Word: symzonia, Frequency: 2
# Word: haniyeh, Frequency: 1
# Word: lahya, Frequency: 1
# Word: herdoniac, Frequency: 1
# Word: salthe, Frequency: 1
# Word: nonviral, Frequency: 1
# Word: grena, Frequency: 2
# Word: paccekabuddha, Frequency: 1
# Word: agss, Frequency: 3
# Word: khami, Frequency: 2
# Word: chuvashes, Frequency: 1
# Word: achsel, Frequency: 1
# Word: scutage, Frequency: 4
# Word: corposant, Frequency: 1
# Word: maschinenpistole, Frequency: 3
# Word: mokarran, Frequency: 2
# Word: aarons, Frequency: 2
# Word: farland, Frequency: 1
# Word: vidyasoochika, Frequency: 1
# Word: claustrophile, Frequency: 1
# Word: laksono, Frequency: 1
# Word: garo, Frequency: 3
# Word: allgemeinen, Frequency: 2
# Word: ramadi, Frequency: 1
# Word: antipasti, Frequency: 1
# Word: forficula, Frequency: 2
# Word: qanat, Frequency: 1
# Word: bojaxhiu, Frequency: 1
# Word: riaz, Frequency: 1
# Word: mediacrypt, Frequency: 3
# Word: agradi, Frequency: 1
# Word: kuropka, Frequency: 2
# Word: pothowar, Frequency: 1
# Word: krafsur, Frequency: 1
# Word: dussault, Frequency: 2
# Word: intragenic, Frequency: 1
# Word: alienatione, Frequency: 1
# Word: cardinalate, Frequency: 1
# Word: alize, Frequency: 2
# Word: hsca, Frequency: 2
# Word: tappe, Frequency: 2
# Word: praeludium, Frequency: 1
# Word: philargos, Frequency: 2
# Word: aneha, Frequency: 1
# Word: hakuseki, Frequency: 2
# Word: explicator, Frequency: 1
# Word: martland, Frequency: 1
# Word: thaipoosam, Frequency: 1
# Word: taikoyaki, Frequency: 1
# Word: deana, Frequency: 1
# Word: stotra, Frequency: 1
# Word: unlistenable, Frequency: 1
# Word: qavua, Frequency: 1
# Word: mccaul, Frequency: 1
# Word: yagher, Frequency: 1
# Word: gelora, Frequency: 1
# Word: johnnycash, Frequency: 1
# Word: abeleus, Frequency: 1
# Word: baillement, Frequency: 1
# ...
# Word: siddharta, Frequency: 2
# Word: leptodora, Frequency: 1
# Word: marella, Frequency: 3
# Word: tappi, Frequency: 1
# Word: mundar, Frequency: 9
# Word: atheletes, Frequency: 1
# Word: resedaceae, Frequency: 2
# Word: limuria, Frequency: 2
# Word: governamentais, Frequency: 1
# Word: pombal, Frequency: 7
# Word: leva, Frequency: 2
# Word: toshkova, Frequency: 2
# Word: warthogs, Frequency: 2
# Word: allocortex, Frequency: 3
# Word: phocas, Frequency: 15
# Word: gymnasts, Frequency: 17
# Word: lambay, Frequency: 1
# Word: floorplan, Frequency: 1
# Word: cleavon, Frequency: 5
# Word: yusab, Frequency: 1
# Word: celia, Frequency: 16
# Word: yphal, Frequency: 1
# Word: eammons, Frequency: 3
# Word: jashub, Frequency: 2
# Word: vafthruthnir, Frequency: 1
# Word: degreaser, Frequency: 2
# Word: carbondioxide, Frequency: 1
# Word: revitalizing, Frequency: 3
# Word: deckhands, Frequency: 1
# Word: acms, Frequency: 3
# Word: magadhan, Frequency: 3
# Word: endoplasmic, Frequency: 27
# Word: mma, Frequency: 21
# Word: lorelai, Frequency: 1
# Word: staggerwing, Frequency: 4
# Word: moag, Frequency: 1
# Word: nailbomber, Frequency: 1
# Word: bostonians, Frequency: 12
# Word: undaunted, Frequency: 6
# Word: ultralow, Frequency: 1
# Word: amunition, Frequency: 2
# Word: jorma, Frequency: 4
# Word: methegammah, Frequency: 1
# Word: pekahiah, Frequency: 4
# Word: giraffes, Frequency: 18
# Word: bosanquet, Frequency: 3
# Word: deaux, Frequency: 1
# Word: djuma, Frequency: 1
# Word: liamm, Frequency: 1
# Word: historial, Frequency: 1
# Word: winona, Frequency: 16
# Word: paderewski, Frequency: 5
# Word: ndia, Frequency: 5
# Word: quazepam, Frequency: 1
# Word: bodytweaking, Frequency: 1
# Word: nicosian, Frequency: 6
# Word: buffalos, Frequency: 1
# Word: zlar, Frequency: 2
# Word: dehydrogenases, Frequency: 2
# Word: ferryboats, Frequency: 4
# Word: narayanpala, Frequency: 1
# Word: malla, Frequency: 5
# Word: bhathais, Frequency: 1
# Word: powersat, Frequency: 1
# Word: sharonville, Frequency: 1
# Word: particularism, Frequency: 7
# Word: christianshavn, Frequency: 1
# Word: extremal, Frequency: 8
# Word: caniforms, Frequency: 3
# Word: talentless, Frequency: 4
# Word: ramis, Frequency: 5
# Word: alguer, Frequency: 3
# Word: barraca, Frequency: 2
# Word: emotionalism, Frequency: 4
# Word: chautauquan, Frequency: 2
# Word: amiodarone, Frequency: 1
# Word: procolonial, Frequency: 1
# Word: dzanga, Frequency: 1
# Word: fula, Frequency: 9
# Word: halilsoy, Frequency: 1
# Word: vaticana, Frequency: 2
# Word: mongolica, Frequency: 3
# Word: pensionable, Frequency: 1
# Word: hamoaze, Frequency: 4
# Word: rezabek, Frequency: 1
# Word: piastre, Frequency: 1
# Word: bukharan, Frequency: 3
# Word: thernal, Frequency: 1
# Word: cumanicus, Frequency: 1
# Word: garcon, Frequency: 2
# Word: capparidaceae, Frequency: 1
# Word: skyways, Frequency: 6
# Word: embrac, Frequency: 1
# Word: aetiology, Frequency: 4
# Word: daube, Frequency: 2
# Word: nicoletta, Frequency: 1
# Word: roncador, Frequency: 1
# Word: screwgate, Frequency: 5
# Word: casuist, Frequency: 2
# Word: copestake, Frequency: 1
# Word: sawdust, Frequency: 12
# Word: verena, Frequency: 3
# Word: haruspicum, Frequency: 1
# Word: coalbrookedale, Frequency: 2
# Word: scribonianus, Frequency: 2
# Word: medullina, Frequency: 1
# Word: picayune, Frequency: 3
# Word: stromateis, Frequency: 7
# Word: rocklands, Frequency: 1
# Word: kanstein, Frequency: 1
# Word: figurations, Frequency: 2
# Word: marinas, Frequency: 4
# Word: athame, Frequency: 1
# Word: icosahedron, Frequency: 48
# Word: vanni, Frequency: 4
# Word: mekab, Frequency: 1
# Word: laboratorio, Frequency: 1
# Word: mohegan, Frequency: 5
# Word: gondal, Frequency: 3
# Word: kosar, Frequency: 17
# Word: poncha, Frequency: 1
# Word: ceca, Frequency: 1
# Word: mcnabb, Frequency: 5
# Word: packerhater, Frequency: 1
# Word: ennstal, Frequency: 1
# Word: jaxx, Frequency: 1
# Word: bicameralism, Frequency: 1
# Word: miaow, Frequency: 1
# Word: maile, Frequency: 1
# Word: humpycase, Frequency: 1
# Word: enthanu, Frequency: 1
# Word: yimsha, Frequency: 1
# Word: ceaulin, Frequency: 1
# Word: flaccid, Frequency: 3
# Word: mattausch, Frequency: 1
# Word: paralyzes, Frequency: 3
# Word: ensalada, Frequency: 2
# Word: muludhara, Frequency: 1
# Word: cannis, Frequency: 1
# Word: caravggio, Frequency: 1
# Word: classist, Frequency: 5
# Word: cinquains, Frequency: 2
# Word: camptothecins, Frequency: 1
# Word: airacobra, Frequency: 2
# Word: padhu, Frequency: 1
# Word: nanten, Frequency: 1
# Word: westmeath, Frequency: 3
# Word: giannettino, Frequency: 3
# Word: fisica, Frequency: 2
# Word: uniformitarianism, Frequency: 21
# Word: videoplay, Frequency: 1
# Word: bracteates, Frequency: 1
# Word: makari, Frequency: 1
# Word: malankara, Frequency: 1
# Word: manesson, Frequency: 1
# Word: finlandization, Frequency: 14
# Word: quaalude, Frequency: 1
# Word: corporative, Frequency: 7
# Word: pinea, Frequency: 3
# Word: garners, Frequency: 5
# Word: spillane, Frequency: 4
# Word: narcosis, Frequency: 4
# Word: quadratures, Frequency: 2
# Word: entorhinal, Frequency: 9
# Word: nodosaurid, Frequency: 1
# Word: ferromagnetism, Frequency: 13
# Word: ameche, Frequency: 4
# Word: heneage, Frequency: 1
# Word: clonaid, Frequency: 6
# Word: matriarchal, Frequency: 3
# Word: tenshinhan, Frequency: 2
# Word: tachi, Frequency: 24
# Word: dabbert, Frequency: 1
# Word: cosmography, Frequency: 11
# Word: blastocyst, Frequency: 6
# Word: serrat, Frequency: 1
# Word: directplay, Frequency: 1
# Word: wads, Frequency: 20
# Word: interrelatedness, Frequency: 1
# Word: upbraided, Frequency: 2
# Word: rucka, Frequency: 2
# Word: exonerate, Frequency: 4
# Word: sparkbrook, Frequency: 1
# Word: turbans, Frequency: 5
# Word: reeland, Frequency: 1
# Word: marith, Frequency: 1
# Word: singaporeans, Frequency: 1
# Word: dyna, Frequency: 4
# Word: himmelfaldne, Frequency: 1
# Word: transmundane, Frequency: 1
# Word: paams, Frequency: 1
# Word: mondrag, Frequency: 4
# Word: macabres, Frequency: 1
# Word: parergon, Frequency: 1
# Word: diatesaron, Frequency: 1
# Word: warlock, Frequency: 6
# Word: innateness, Frequency: 4
# Word: ehecatl, Frequency: 1
# Word: wakahiru, Frequency: 1
# Word: adroanzi, Frequency: 1
# Word: lateraled, Frequency: 2
# Word: ovates, Frequency: 1
# Word: granule, Frequency: 5
# Word: parolas, Frequency: 2
# Word: startposition, Frequency: 6
# Word: cunedda, Frequency: 2
# Word: sumatrans, Frequency: 1
# Word: harn, Frequency: 1
# Word: neofunctionalist, Frequency: 1
# Word: anytravels, Frequency: 1
# Word: toshka, Frequency: 1
# Word: nawd, Frequency: 1
# Word: vabariik, Frequency: 1
# Word: zagwe, Frequency: 2
# Word: ramacharitamanasa, Frequency: 2
# Word: aouad, Frequency: 1
# Word: zapffe, Frequency: 1
# Word: brynaich, Frequency: 1
# Word: fountainbridge, Frequency: 1
# Word: jastrz, Frequency: 1
# Word: schoolwas, Frequency: 1
# Word: endtas, Frequency: 1
# Word: wigglesworthia, Frequency: 4
# Word: palamas, Frequency: 13
# Word: natroun, Frequency: 1
# Word: pogesania, Frequency: 3
# Word: ekonomiczna, Frequency: 2
# Word: liberalerna, Frequency: 1
# Word: sauguet, Frequency: 1
# Word: makong, Frequency: 1
# Word: zaragosa, Frequency: 1
# Word: maldon, Frequency: 2
# Word: automatons, Frequency: 3
# Word: nanban, Frequency: 4
# Word: hwangje, Frequency: 4
# Word: kaunis, Frequency: 1
# Word: vammus, Frequency: 1
# Word: parseldama, Frequency: 1
# Word: carlota, Frequency: 2
# Word: hinitial, Frequency: 2
# Word: canibus, Frequency: 2
# Word: tarsk, Frequency: 1
# Word: ukra, Frequency: 2
# Word: kaptata, Frequency: 1
# Word: hashihito, Frequency: 6
# Word: carrilo, Frequency: 1
# Word: vicario, Frequency: 1
# Word: clupea, Frequency: 1
# Word: courau, Frequency: 1
# Word: launius, Frequency: 2
# Word: efficace, Frequency: 1
# Word: danceability, Frequency: 1
# Word: zangiku, Frequency: 1
# Word: kamikakushi, Frequency: 2
# Word: thornham, Frequency: 1
# Word: ignac, Frequency: 1
# Word: votyak, Frequency: 1
# Word: ohcejohka, Frequency: 1
# Word: singmirwas, Frequency: 1
# Word: balestre, Frequency: 1
# Word: barrichello, Frequency: 7
# Word: ottla, Frequency: 3
# Word: fractus, Frequency: 4
# Word: apophysis, Frequency: 1
# Word: dratch, Frequency: 3
# Word: salonga, Frequency: 3
# Word: sechehaye, Frequency: 2
# Word: metaxas, Frequency: 9
# Word: kissane, Frequency: 1
# Word: pastafarianism, Frequency: 1
# Word: farmable, Frequency: 1
# Word: cavalese, Frequency: 2
# Word: algorithim, Frequency: 1
# Word: mixal, Frequency: 1
# Word: cyberchondriac, Frequency: 1
# Word: dislang, Frequency: 1
# Word: hackintosh, Frequency: 1
# Word: hasp, Frequency: 1
# Word: distaff, Frequency: 2
# Word: rheinfranken, Frequency: 1
# Word: natto, Frequency: 5
# Word: stardard, Frequency: 1
# Word: galaxia, Frequency: 2
# Word: appellees, Frequency: 1
# Word: sanjurjo, Frequency: 3
# Word: gitanos, Frequency: 7
# Word: cabras, Frequency: 1
# Word: conversationalist, Frequency: 2
# Word: paraquet, Frequency: 1
# Word: propagator, Frequency: 4
# Word: kezia, Frequency: 1
# Word: teamleader, Frequency: 2
# Word: laboratores, Frequency: 1
# Word: luokkasota, Frequency: 1
# Word: torpparit, Frequency: 1
# Word: iznang, Frequency: 1
# Word: qitara, Frequency: 1
# Word: geutan, Frequency: 2
# Word: panentheist, Frequency: 1
# Word: nationis, Frequency: 2
# Word: chimaltenango, Frequency: 2
# Word: verhaften, Frequency: 1
# Word: bagme, Frequency: 1
# Word: naestved, Frequency: 1
# Word: belorusskaya, Frequency: 1
# Word: kotaro, Frequency: 2
# Word: wissenschaftslehre, Frequency: 5
# Word: wesat, Frequency: 1
# Word: kwahu, Frequency: 12
# Word: koforidua, Frequency: 2
# Word: skyvan, Frequency: 1
# Word: administracji, Frequency: 2
# Word: markezinis, Frequency: 2
# Word: rearraigned, Frequency: 1
# Word: taspar, Frequency: 1
# Word: accessorized, Frequency: 2
# Word: caddyshack, Frequency: 1
# Word: gangotri, Frequency: 4
# Word: uigar, Frequency: 1
# Word: taybili, Frequency: 1
# Word: causis, Frequency: 2
# Word: circulatores, Frequency: 1
# Word: psychedelia, Frequency: 4
# Word: cultureandheritage, Frequency: 1
# Word: unmasks, Frequency: 1
# Word: dammerman, Frequency: 1
# Word: kningar, Frequency: 1
# Word: experiancing, Frequency: 1
# Word: rasputye, Frequency: 1
# Word: transduce, Frequency: 2
# Word: labicus, Frequency: 1
# Word: blab, Frequency: 1
# Word: fehmarn, Frequency: 4
# Word: seagry, Frequency: 1
# Word: mannerliebe, Frequency: 1
# Word: darmst, Frequency: 1
# Word: cumae, Frequency: 5
# Word: haides, Frequency: 1
# Word: dumarsais, Frequency: 2
# Word: marath, Frequency: 1
# Word: masseur, Frequency: 1
# Word: varyingly, Frequency: 1
# Word: accredit, Frequency: 1
# Word: storyspace, Frequency: 2
# Word: sexualism, Frequency: 2
# Word: radioiodine, Frequency: 8
# Word: powerade, Frequency: 2
# Word: biohacker, Frequency: 1
# Word: fortinbras, Frequency: 5
# Word: eratosth, Frequency: 1
# Word: acquifer, Frequency: 1
# Word: langugae, Frequency: 1
# Word: cordobas, Frequency: 6
# Word: drachm, Frequency: 1
# Word: cumana, Frequency: 1
# Word: azizah, Frequency: 2
# Word: crazewire, Frequency: 1
# Word: dirat, Frequency: 1
# Word: chambering, Frequency: 3
# Word: particularises, Frequency: 1
# Word: tosafists, Frequency: 2
# Word: pakhir, Frequency: 1
# Word: kkea, Frequency: 1
# Word: taq, Frequency: 4
# Word: yaron, Frequency: 1
# Word: naaldwijk, Frequency: 1
# Word: isaacks, Frequency: 1
# Word: obaliq, Frequency: 1
# Word: nieszawa, Frequency: 1
# Word: handa, Frequency: 1
# Word: mastodont, Frequency: 1
# Word: hellzapoppin, Frequency: 2
# Word: macadam, Frequency: 2
# Word: fisgard, Frequency: 1
# Word: fane, Frequency: 1
# Word: mallsnerd, Frequency: 1
# Word: diaktoros, Frequency: 1
# Word: rahnj, Frequency: 1
# Word: amus, Frequency: 5
# Word: parotitis, Frequency: 1
# Word: gharraf, Frequency: 2
# Word: viareggio, Frequency: 2
# Word: bulbocavernosus, Frequency: 1
# Word: unsolveable, Frequency: 1
# Word: vattel, Frequency: 2
# Word: sjgames, Frequency: 2
# Word: moscardini, Frequency: 1
# Word: pastiera, Frequency: 1
# Word: danby, Frequency: 5
# Word: bakkum, Frequency: 1
# Word: myhra, Frequency: 1
# Word: margalioth, Frequency: 1
# Word: djorkaeff, Frequency: 2
# Word: mitnakhalim, Frequency: 1
# Word: dindshenchas, Frequency: 3
# Word: kabupaten, Frequency: 2
# Word: jacopone, Frequency: 1
# Word: naicho, Frequency: 1
# Word: pisanello, Frequency: 1
# Word: siamo, Frequency: 1
# Word: nadisha, Frequency: 1
# Word: palla, Frequency: 1
# Word: nemawashi, Frequency: 1
# Word: cantabrigiam, Frequency: 1
# Word: jugashvili, Frequency: 1
# Word: megalosaurs, Frequency: 1
# Word: carmenta, Frequency: 2
# Word: aldie, Frequency: 1
# Word: siza, Frequency: 1
# Word: kenenisa, Frequency: 1
# Word: maykov, Frequency: 1
# Word: franceweb, Frequency: 1
# Word: mannor, Frequency: 1
# Word: lexa, Frequency: 2
# Word: chalkie, Frequency: 1
# Word: jaou, Frequency: 2
# Word: huusman, Frequency: 1
# Word: umarkot, Frequency: 1
# Word: shirataki, Frequency: 1
# Word: iravatham, Frequency: 1
# Word: jainsoc, Frequency: 1
# Word: albik, Frequency: 1
# Word: souphanouvong, Frequency: 1
# Word: beisamoun, Frequency: 1
# Word: esacpe, Frequency: 1
# Word: swaggered, Frequency: 1
# Word: kashruth, Frequency: 2
# Word: subjectmatter, Frequency: 1
# Word: ambersons, Frequency: 5
# Word: heeresversuchsanstalt, Frequency: 1
# Word: shamelessness, Frequency: 1
# Word: overloads, Frequency: 1
# Word: daynes, Frequency: 1
# Word: caudill, Frequency: 1
# Word: emeritation, Frequency: 1
# Word: agen, Frequency: 1
# Word: platini, Frequency: 2
# Word: voordat, Frequency: 1
# Word: mandgelis, Frequency: 1
# Word: nursultan, Frequency: 9
# Word: tyuratam, Frequency: 1
# Word: changbaishan, Frequency: 1
# Word: adaukt, Frequency: 1
# Word: banavasi, Frequency: 1
# Word: handcount, Frequency: 1
# Word: forbearers, Frequency: 1
# Word: qabbola, Frequency: 1
# Word: hexoctahedral, Frequency: 1
# Word: staurolite, Frequency: 2
# Word: yantarny, Frequency: 1
# Word: darkehmen, Frequency: 1
# Word: savernik, Frequency: 1
# Word: virtualisation, Frequency: 1
# Word: gadhafi, Frequency: 1
# Word: biyah, Frequency: 1
# Word: colchicaceae, Frequency: 1
# Word: ignoratio, Frequency: 3
# Word: kandji, Frequency: 2
# Word: alakhder, Frequency: 1
# Word: galeopsis, Frequency: 1
# Word: lionshare, Frequency: 1
# Word: bisland, Frequency: 1
# Word: faceretis, Frequency: 1
# Word: longbeards, Frequency: 2
# Word: apologiam, Frequency: 1
# Word: papists, Frequency: 1
# Word: hemiauchenia, Frequency: 1
# Word: llamazap, Frequency: 1
# Word: mahakassapa, Frequency: 1
# Word: kadam, Frequency: 1
# Word: scincomorpha, Frequency: 2
# Word: chidambaram, Frequency: 2
# Word: anager, Frequency: 2
# Word: vitamperdit, Frequency: 1
# Word: caerdroia, Frequency: 1
# Word: pitane, Frequency: 1
# Word: lakonias, Frequency: 2
# Word: crano, Frequency: 1
# Word: saamna, Frequency: 1
# Word: procrastinator, Frequency: 1
# Word: eolagurus, Frequency: 3
# Word: jajaja, Frequency: 1
# Word: pacelle, Frequency: 1
# Word: fischiato, Frequency: 1
# Word: chalion, Frequency: 5
# Word: pelycosaurs, Frequency: 2
# Word: biosatellite, Frequency: 1
# Word: maurolico, Frequency: 2
# Word: qurayza, Frequency: 5
# Word: chicamicamico, Frequency: 1
# Word: tiako, Frequency: 1
# Word: alephmostly, Frequency: 1
# Word: miladinov, Frequency: 3
# Word: srbija, Frequency: 2
# Word: nkhotakota, Frequency: 5
# Word: alifu, Frequency: 2
# Word: ikatel, Frequency: 1
# Word: mappls, Frequency: 1
# Word: basarabia, Frequency: 1
# Word: matronalia, Frequency: 1
# Word: waireka, Frequency: 1
# Word: corabi, Frequency: 2
# Word: drakconnect, Frequency: 1
# Word: viscerally, Frequency: 1
# Word: laundries, Frequency: 2
# Word: esaamlg, Frequency: 1
# Word: radicalise, Frequency: 1
# Word: pachifractal, Frequency: 2
# Word: microsporidians, Frequency: 1
# Word: jaiminiya, Frequency: 1
# Word: savara, Frequency: 1
# Word: gobat, Frequency: 2
# Word: magnetising, Frequency: 1
# Word: schlottau, Frequency: 1
# Word: papyrologie, Frequency: 1
# Word: bocadillos, Frequency: 1
# Word: apoorva, Frequency: 1
# Word: mapple, Frequency: 1
# Word: caldeiro, Frequency: 1
# Word: plazynski, Frequency: 1
# Word: extracelluar, Frequency: 1
# Word: nathasha, Frequency: 1
# Word: blahuj, Frequency: 1
# Word: tharpe, Frequency: 1
# Word: javo, Frequency: 1
# Word: viano, Frequency: 1
# Word: morrigania, Frequency: 1
# Word: dauntingly, Frequency: 1
# Word: semiautobiograpical, Frequency: 1
# Word: mazury, Frequency: 5
# Word: jameelah, Frequency: 2
# Word: albipictus, Frequency: 1
# Word: capturedor, Frequency: 1
# Word: kodaikanal, Frequency: 1
# Word: pachanga, Frequency: 2
# Word: vaidarbhi, Frequency: 1
# Word: abja, Frequency: 1
# Word: merhgahr, Frequency: 1
# Word: vaisvilkas, Frequency: 1
# Word: diisocyanate, Frequency: 1
# Word: khass, Frequency: 1
# Word: ecaz, Frequency: 1
# Word: fanvid, Frequency: 1
# Word: draquecito, Frequency: 1
# Word: passantinos, Frequency: 1

# %% [markdown]
# The reduceByKey transformation aggregates the counts of each word by summing up the values associated with the same key (word), resulting in word_frequencies.
# Filtering Words:
#
# Using the filter transformation, words containing the letter 'a' are filtered from word_frequencies, resulting in words_with_a.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, corr
spark = SparkSession.builder \
    .appName("IrisDataFrame") \
    .getOrCreate()

iris_df = spark.read.json("/content/drive/MyDrive/Datasets/iris.json")

correlation = iris_df.select(corr("petalLength", "petalWidth")).collect()[0][0]
print("Pearson Correlation between petalLength and petalWidth:", correlation)
filtered_df = iris_df.filter(col("petalLength") >= 1.4).select("sepalLength", "sepalWidth", "species")
filtered_df.show()
spark.stop()
# Out:
# Pearson Correlation between petalLength and petalWidth: 0.962865431402796
# +-----------+----------+-------+
# |sepalLength|sepalWidth|species|
# +-----------+----------+-------+
# |        5.1|       3.5| setosa|
# |        4.9|       3.0| setosa|
# |        4.6|       3.1| setosa|
# |        5.0|       3.6| setosa|
# |        5.4|       3.9| setosa|
# |        4.6|       3.4| setosa|
# |        5.0|       3.4| setosa|
# |        4.4|       2.9| setosa|
# |        4.9|       3.1| setosa|
# |        5.4|       3.7| setosa|
# |        4.8|       3.4| setosa|
# |        4.8|       3.0| setosa|
# |        5.7|       4.4| setosa|
# |        5.1|       3.5| setosa|
# |        5.7|       3.8| setosa|
# |        5.1|       3.8| setosa|
# |        5.4|       3.4| setosa|
# |        5.1|       3.7| setosa|
# |        5.1|       3.3| setosa|
# |        4.8|       3.4| setosa|
# +-----------+----------+-------+
# only showing top 20 rows

# %% [markdown]
# The corr() function from pyspark.sql.functions is used to calculate the Pearson correlation between the columns "petalLength" and "petalWidth" in the iris_df DataFrame. The result is collected using collect() and indexed to retrieve the correlation value.
