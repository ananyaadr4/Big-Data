# %%
import pandas as pd
import requests

# %%
import requests

url = "https://mashape-community-urban-dictionary.p.rapidapi.com/define"

querystring = {"term":"wat"}

headers = {
	"X-RapidAPI-Key": "06e1cc75edmshe6288875c7206afp171bb3jsn527ad23fad3e",
	"X-RapidAPI-Host": "mashape-community-urban-dictionary.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'list': [{'definition': 'The only [proper] [response] to something that makes absolutely [no sense].', 'permalink': 'http://wat.urbanup.com/3322419', 'thumbs_up': 3985, 'author': 'watwat', 'word': 'wat', 'defid': 3322419, 'current_vote': '', 'written_on': '2008-09-04T09:15:08.000Z', 'example': "1: If all the animals on the [equator] were capable of [flattery], Halloween and Easter would fall on the same day.\r\n2: wat\r\n\r\n1: Wow your cock is almost as big as my dad's.\r\n2: wat\r\n\r\n1: I accidentially a whole [coke bottle]\r\n2: You accidentially what?\r\n1: A whole coke bottle\r\n2: wat", 'thumbs_down': 443}, {'definition': 'Slang.  Indicates [confusion] or [a need] for [clarification].  Statement/question.', 'permalink': 'http://wat.urbanup.com/1308686', 'thumbs_up': 1218, 'author': 'stewpidwhytemayun', 'word': 'wat', 'defid': 1308686, 'current_vote': '', 'written_on': '2005-06-08T23:20:56.000Z', 'example': '1: "[lolz] Yea sex is great and everything but its way too overrated
# ...

# %%
data = pd.DataFrame(response.json()['list'])[['definition','permalink','thumbs_up','defid','word','author','written_on','example']]

# %%
data
# Out:
#                                           definition  \
# 0  The only [proper] [response] to something that...
# 1  Slang.  Indicates [confusion] or [a need] for ...
# 2  ‎[Wat] is the internet troll equivalent to wha...
# 3  A word, that when perfectly placed, is a power...
# 4  Short form of "what". Is usually used by peopl...
# 5  What one says when they're [devoid] of any par...
# 6  [Thai] [temple], found all over [Thailand]. Pr...
# 7  [the meme] version of what you just [take out]...
# 8  Wat is short for "What" but is only spelt "Wat...
# 9  An [utterance] one would say if [someone else]...
#
#                          permalink  thumbs_up     defid word  \
# 0   http://wat.urbanup.com/3322419       3985   3322419  wat
# 1   http://wat.urbanup.com/1308686       1218   1308686  wat
# 2   http://wat.urbanup.com/5112312        214   5112312  wat
# 3   http://wat.urbanup.com/3351192        360   3351192  wat
# 4   http://wat.urbanup.com/3621253        310   3621253  wat
# ...

# %%
import requests

url = "https://matchilling-chuck-norris-jokes-v1.p.rapidapi.com/jokes/random"

headers = {
	"accept": "application/json",
	"X-RapidAPI-Key": "06e1cc75edmshe6288875c7206afp171bb3jsn527ad23fad3e",
	"X-RapidAPI-Host": "matchilling-chuck-norris-jokes-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'categories': [], 'created_at': '2020-01-05 13:42:19.576875', 'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png', 'id': 'oH5TGBkUR_2tEnQWB4llsg', 'updated_at': '2020-01-05 13:42:19.576875', 'url': 'https://api.chucknorris.io/jokes/oH5TGBkUR_2tEnQWB4llsg', 'value': 'Chuck Norris drinks bear milk.'}

# %%
import requests

url = "https://free-nba.p.rapidapi.com/players"

querystring = {"page":"0","per_page":"25"}

headers = {
	"X-RapidAPI-Key": "06e1cc75edmshe6288875c7206afp171bb3jsn527ad23fad3e",
	"X-RapidAPI-Host": "free-nba.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': [{'id': 46391370, 'first_name': 'Jake', 'height_feet': None, 'height_inches': None, 'last_name': 'Carter', 'position': '', 'team': {'id': 50, 'abbreviation': 'DN', 'city': '', 'conference': '    ', 'division': '', 'full_name': 'Denver Nuggets', 'name': 'Denver Nuggets'}, 'weight_pounds': None}, {'id': 2144, 'first_name': 'Rakeem', 'height_feet': None, 'height_inches': None, 'last_name': 'Christmas', 'position': '', 'team': {'id': 12, 'abbreviation': 'IND', 'city': 'Indiana', 'conference': 'East', 'division': 'Central', 'full_name': 'Indiana Pacers', 'name': 'Pacers'}, 'weight_pounds': None}, {'id': 46391383, 'first_name': 'Bill', 'height_feet': None, 'height_inches': None, 'last_name': 'Closs', 'position': '', 'team': {'id': 10, 'abbreviation': 'GSW', 'city': 'Golden State', 'conference': 'West', 'division': 'Pacific', 'full_name': 'Golden State Warriors', 'name': 'Warriors'}, 'weight_pounds': None}, {'id': 122, 'first_name': 'Angel', 'height_feet': 6, 'height_inches': 10, '
# ...

# %%
data1 = pd.DataFrame(response.json()['data'])[['id','first_name', 'height_feet', 'height_inches' ,'last_name', 'position']]

# %%
data1.head(10)
# Out:
#          id first_name  height_feet  height_inches    last_name position
# 0  46391370       Jake          NaN            NaN       Carter
# 1      2144     Rakeem          NaN            NaN    Christmas
# 2  46391383       Bill          NaN            NaN        Closs
# 3       122      Angel          6.0           10.0      Delgado        C
# 4       123    Matthew          6.0            4.0  Dellavedova        G
# 5      2819     Fennis          NaN            NaN        Dembo
# 6       149     Keenan          NaN            NaN        Evans        G
# 7      2299      Larry          NaN            NaN        Demic
# 8       124       Luol          6.0            9.0         Deng        F
# 9      2608      Kenny          NaN            NaN      Dennard
